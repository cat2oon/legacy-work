# %% [markdown]
# # ellipse fitting

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse

# %%
def load_modules():
    sys.path.append("../../")
    # %run ../../ac/visualizer/plotter.py
    # %run ../../al/maths/geos/ellipse.py
    # %run ../../al/optimize/ellipse/ellipse.py
load_modules()

# %%
contours = make_ellipse_contours(center=(0, 0), width=3, height=5)

# %%
center, width, height, phi = fit_ellipse(np.array(contours))
print(center, width, height, phi)
# Out:
# [0.2549746411707331, 0.25761705805522556] 3.027340656107515 4.994116523229872 0.6275580270967196

# %%
ax = plot_points(contours)
ax.add_patch(make_ellipse(center, 2*width, 2*height, phi))
