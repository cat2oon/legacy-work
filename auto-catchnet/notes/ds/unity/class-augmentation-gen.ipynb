# %% [markdown]
# # unity class (1681) augmentation Gen

# %% [markdown]
# # imports

# %%
import sys

sys.path.append("../../../")
# %run ../../../ds/unity/npz/gen.py
# %run ../../../ac/visualizer/plotter.py
# %run ../../../ac/common/images.py

# %% [markdown]
# # resources

# %%
# npz_base_path = "/home/chy/archive-data/processed/unity-class-shuffled-npz"
npz_base_path = "/home/chy/labs/samples"

# %% [markdown]
# # generator

# %%
# igen = UnityEyePoseGenerator(npz_base_path, purpose=Purpose.ALL, is_item_mode=True)

# %%
# item = igen[0][0]

# %% [markdown]
# # (720, 1280) 기준 15~50cm 눈 픽셀 크기
#
# ### (56, 112)
#
# <br>
#
# |w|h|d|
# |---|---|---|
# |200|100|---|
# |150|80|---|
# |90|60|---|
# |110|50|---|
# |90|40|---|

# %%
ugen = UnityEyePoseGenerator(npz_base_path,
                             batch_size=5000,
                             purpose=Purpose.ALL, 
                             use_aug=False, 
                             use_postprocess=False)
# Out:
# *** meta verify complete [Unknown] ***

# %% [markdown]
# # find broken

# %%
sample_npz_path = "/home/chy/labs/samples/unity-0000.npz"
npz = np.load(sample_npz_path)

# %%
images, metas = npz['images'], npz['metas']
# for idx, img in enumerate(npz['images']):
#     decode_img(img)
#     print(idx)

# %%
npz78 = UnityItem.from_npz_path("/home/chy/archive-data/processed/unity-class-shuffled-npz/unity-00078.npz")

# %%
npz78[3114] = npz78[0]

# %%
UnityItem.to_npz("/home/chy/archive-data/processed/unity-class-shuffled-npz/", npz78, 78)

# %% [markdown]
# # vis aug

# %%
print(imgs[0].shape)
for i, l in zip(imgs, labels):
    show_image(i, fig_size=(2,2))
# Out:
# (56, 112, 1)
