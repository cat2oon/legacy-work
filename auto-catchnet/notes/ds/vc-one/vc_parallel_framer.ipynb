# %% [markdown]
# # imports

# %%
import os
import sys

sys.path.append("../../../")
# %run ../../../ds/vcone/framer.py

# %% [markdown]
# # resources

# %%
base_path = "/home/chy/archive-data/bench/mturk/Freezed"
save_base_path = "/home/chy/archive-data/processed/vc-one/frames"

# %% [markdown]
# # npz-roller

# %%
framer = Framer(base_path, save_base_path)

# %%
framer.to_npz_all()
# Out:
# >>>>>> 3K5TEWLKGWUY4P0DS5Z8ZOH1NVPIV4
# /home/chy/archive-data/bench/mturk/Freezed/3K5TEWLKGWUY4P0DS5Z8ZOH1NVPIV4/3/eye-record-3-1-0.mp4
# >>>>>> 3K5TEWLKGWUY4P0DS5Z8ZOH1NVPIV4
# /home/chy/archive-data/bench/mturk/Freezed/3K5TEWLKGWUY4P0DS5Z8ZOH1NVPIV4/3/eye-record-3-0-0.mp4
# >>>>>> 3K5TEWLKGWUY4P0DS5Z8ZOH1NVPIV4
# /home/chy/archive-data/bench/mturk/Freezed/3K5TEWLKGWUY4P0DS5Z8ZOH1NVPIV4/3/eye-record-3-2-0.mp4
# >>>>>> 3K5TEWLKGWUY4P0DS5Z8ZOH1NVPIV4
# /home/chy/archive-data/bench/mturk/Freezed/3K5TEWLKGWUY4P0DS5Z8ZOH1NVPIV4/2/eye-record-2-1-3.mp4
# >>>>>> 3K5TEWLKGWUY4P0DS5Z8ZOH1NVPIV4
# /home/chy/archive-data/bench/mturk/Freezed/3K5TEWLKGWUY4P0DS5Z8ZOH1NVPIV4/2/eye-record-2-1-0.mp4
# >>>>>> 3K5TEWLKGWUY4P0DS5Z8ZOH1NVPIV4
# /home/chy/archive-data/bench/mturk/Freezed/3K5TEWLKGWUY4P0DS5Z8ZOH1NVPIV4/2/eye-record-2-0-2.mp4
# >>>>>> 3K5TEWLKGWUY4P0DS5Z8ZOH1NVPIV4
# /home/chy/archive-data/bench/mturk/Freezed/3K5TEWLKGWUY4P0DS5Z8ZOH1NVPIV4/2/eye-record-2-2-2.mp4
# ...
