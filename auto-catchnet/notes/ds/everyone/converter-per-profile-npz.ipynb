# %% [markdown]
# # npz -> npz (per profile)

# %% [markdown]
# # import

# %%
import os
import sys
sys.path.append("../../../")

# %run ../../../ds/everyone/npz/main.py --dataset "J:/eyes_tmp/" --outdir "S:/datasets/processed/everyone-npz-profile/"
# Out:
# >>> index everyone from: J:/eyes_tmp/
# indexing done at profile [00002] num item:56
# indexing done at profile [00003] num item:86
# indexing done at profile [00005] num item:17
# indexing done at profile [00006] num item:105
# indexing done at profile [00010] num item:1926
# indexing done at profile [00024] num item:96
# indexing done at profile [00028] num item:798
# indexing done at profile [00033] num item:826
# indexing done at profile [00034] num item:708
# indexing done at profile [00087] num item:36
# indexing done at profile [00089] num item:11
# indexing done at profile [00097] num item:329
# indexing done at profile [00098] num item:477
# indexing done at profile [00099] num item:1026
# indexing done at profile [00102] num item:579
# indexing done at profile [00103] num item:162
# indexing done at profile [00104] num item:1374
# indexing done at profile [00110] num item:677
# indexing done at profile [00114] num item:3
# indexing done at profile [00117] num item:1328
# ...
