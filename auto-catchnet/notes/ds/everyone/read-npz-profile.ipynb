# %% [markdown]
# # imports

# %%
import sys
import matplotlib.pyplot as plt
# %matplotlib inline

sys.path.append("../../../")
# %run ../../../ac/visulaizer/plotter.py
# %run ../../../ds/everyone/npz/profile_generator.py
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # resources

# %%
npz_path = "S:\datasets\processed\everyone-npz-profile"

# %% [markdown]
# # generator

# %%
gen = EveryoneProfileGenerator(npz_path)
print(len(gen))
# Out:
# 20

# %% [markdown]
# # visualize

# %%
x, y = gen[0]
print(x[0].shape)
show_image(x[2])
# Out:
# (640, 480, 3)
