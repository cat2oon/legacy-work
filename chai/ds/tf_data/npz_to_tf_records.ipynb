# %% [markdown]
# # TFRecord for MAML++

# %%
from npz_to_tf_records import *

# %%
def sanity_check(npz_path):
    import pprint
    npz = np.load(npz_path, allow_pickle=True)
    pprint.pprint(npz.files)
    pprint.pprint(npz['summary'])
    pprint.pprint(npz['meta'][1])

out_root_path = 'N:\\psy\\'
npz_root_path = 'N:\\everyone-npz\\'
sanity_check(npz_root_path + '/profile-03450.npz')
# Out:
# ['summary', 'meta', 'frames']
# array({'profile_id': '03450', 'num_frames': 1032, 'num_face_detect': 983, 'num_eye_detect': 701, 'device': 'iphone 5'},
#       dtype=object)
# {'face_grid_rect': {'h': 11, 'w': 11, 'x': 8, 'y': 12},
#  'face_grid_valid': True,
#  'face_rect': {'h': 268.8, 'w': 268.8, 'x': 91.60001, 'y': 287.6},
#  'face_valid': True,
#  'frame_name': '00001.jpg',
#  'left_eye_rect': {'h': 80.8, 'w': 80.8, 'x': 126.72, 'y': 45.11998},
#  'left_eye_valid': True,
#  'orientation': 1,
#  'right_eye_rect': {'h': 80.8, 'w': 80.8, 'x': 5.520004, 'y': 45.11998},
#  'right_eye_valid': True,
#  'screen_hw': {'h': 568, 'w': 320},
#  'target_dist': {'x': -0.969375, 'y': -7.52597535211},
#  'target_id': 0,
#  'target_pts': {'x': 100, 'y': 406},
#  'target_time': 0.712456}

# %% [markdown]
# # 레코드 변환

# %%
convert(npz_root_path, out_root_path)
# Out:
# 최종 선정 프로파일 개수: 1187
# Executor[Executor[ 1 ] running
#  0 ] running
# Executor[ 2 ] running
# Executor[ 3 ] running
# Executor[ 4 ] running
# Executor[ 5 ] running
# Executor[ Executor[ 7 ] running
# 6 ] running
# Executor[ 8 Executor[ 9] running
#  ] running
# Executor[ 10 ] running
# Executor[ 11 ] running
# >>> Load: /home/elvin/banner/mnt/ssd3/everyone-npz/profile-01425.npz
# >>> Load: /home/elvin/banner/mnt/ssd3/everyone-npz/profile-01379.npz
# >>> Load: /home/elvin/banner/mnt/ssd3/everyone-npz/profile-02136.npz
# >>> Load: /home/elvin/banner/mnt/ssd3/everyone-npz/profile-01247.npz
# >>> Load: /home/elvin/banner/mnt/ssd3/everyone-npz/profile-01171.npz
# >>> Load: /home/elvin/banner/mnt/ssd3/everyone-npz/profile-01698.npz
# >>> Load: /home/elvin/banner/mnt/ssd3/everyone-npz/profile-01979.npz
# >>> Load: /home/elvin/banner/mnt/ssd3/everyone-npz/profile-01391.npz
# >>> Load:>>> Load: /home/elvin/banner/mnt/ssd3/everyone-npz/profile-02047.npz
# ...

# %% [markdown]
# # 변환 레코드 시각화
